# %% [markdown]
# <a href="https://colab.research.google.com/github/Sashka1101/TFG_Gender_Bias/blob/main/ESTE_ES_EL_BUENO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
pip install matplot
# Out:
# Collecting matplot
#   Downloading matplot-0.1.9-py2.py3-none-any.whl (5.0 kB)
# Collecting pyloco>=0.0.134 (from matplot)
#   Downloading pyloco-0.0.139-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from matplot) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (2.8.2)
# Collecting ushlex (from pyloco>=0.0.134->matplot)
#   Downloading ushlex-0.99.1.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from pyloco>=0.0.134->matplot) (1.7.0)
# Collecting twine (from pyloco>=0.0.134->matplot)
#   Downloading twine-5.0.0-py3-none-any.whl (37 kB)
# Collecting typing (from pyloco>=0.0.134->matplot)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting SimpleWebSocketServer (from pyloco>=0.0.134->matplot)
#   Downloading SimpleWebSocketServer-0.1.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.16.0)
# Collecting pkginfo>=1.8.1 (from twine->pyloco>=0.0.134->matplot)
#   Downloading pkginfo-1.10.0-py3-none-any.whl (30 kB)
# Collecting readme-renderer>=35.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading readme_renderer-43.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from twine->pyloco>=0.0.134->matplot) (2.31.0)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from twine->pyloco>=0.0.134->matplot) (2.0.7)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.10/dist-packages (from twine->pyloco>=0.0.134->matplot) (7.0.2)
# Requirement already satisfied: keyring>=15.1 in /usr/lib/python3/dist-packages (from twine->pyloco>=0.0.134->matplot) (23.5.0)
# Requirement already satisfied: rfc3986>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from twine->pyloco>=0.0.134->matplot) (1.5.0)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from twine->pyloco>=0.0.134->matplot) (13.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=3.6->twine->pyloco>=0.0.134->matplot) (3.17.0)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading nh3-0.2.15-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: docutils>=0.13.1 in /usr/local/lib/python3.10/dist-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.18.1)
# Requirement already satisfied: Pygments>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.16.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.2)
# Building wheels for collected packages: SimpleWebSocketServer, typing, ushlex
#   Building wheel for SimpleWebSocketServer (setup.py) ... done
#   Created wheel for SimpleWebSocketServer: filename=SimpleWebSocketServer-0.1.2-py3-none-any.whl size=9664 sha256=ae9a5e4d138bbb814cfbed442b622d1aaf1ebf06116d3260ae88618dc3e62c56
#   Stored in directory: /root/.cache/pip/wheels/af/cb/9d/23ef01c9c26b978be6d29ed456d7348abd0e96b1563049bd63
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26304 sha256=831ddd36855ea06e51a5124d338c008c6dc520444387f14c4a51a3a58c602d68
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
#   Building wheel for ushlex (setup.py) ... done
#   Created wheel for ushlex: filename=ushlex-0.99.1-py3-none-any.whl size=4394 sha256=0b76474be25e6ce3e25b81967030a468c97120b3825cdb64a3f61b86ea26e482
#   Stored in directory: /root/.cache/pip/wheels/fd/e4/80/4de44668798392eb2f5b24f0130df2f5d28b43cb256bf9c1f9
# Successfully built SimpleWebSocketServer typing ushlex
# Installing collected packages: ushlex, SimpleWebSocketServer, nh3, typing, readme-renderer, pkginfo, requests-toolbelt, twine, pyloco, matplot
# Successfully installed SimpleWebSocketServer-0.1.2 matplot-0.1.9 nh3-0.2.15 pkginfo-1.10.0 pyloco-0.0.139 readme-renderer-43.0 requests-toolbelt-1.0.0 twine-5.0.0 typing-3.7.4.3 ushlex-0.99.1

# %%
pip install Word2Vec
# Out:
# Collecting Word2Vec
#   Downloading word2vec-0.11.1.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 706.4 kB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from Word2Vec) (1.25.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from Word2Vec) (1.3.2)
# Building wheels for collected packages: Word2Vec
#   Building wheel for Word2Vec (pyproject.toml) ... done
#   Created wheel for Word2Vec: filename=word2vec-0.11.1-py2.py3-none-any.whl size=141242 sha256=0c66dc0986020675d9674c1f9880854b471d4b6830e4d68198b69875876cdabc
#   Stored in directory: /root/.cache/pip/wheels/6a/fa/d1/e03e8c10e0e2aa5c7b6e2b46b4a1c715d140283853937bb4b1
# Successfully built Word2Vec
# Installing collected packages: Word2Vec
# Successfully installed Word2Vec-0.11.1

# %%
pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in /usr/local/lib/python3.10/dist-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.2.2)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.3.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from gensim.models import Word2Vec
import multiprocessing
import nltk
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
import matplotlib.pyplot as plt
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import googletrans
from googletrans import Translator
import csv
from collections import Counter
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download("omw-1.4")


# Función para traducir un texto muy largo
def traducir_texto_largo(texto):
    # Dividir el texto en fragmentos más pequeños para evitar errores
    fragmentos = [texto[i:i+5000] for i in range(0, len(texto), 5000)]
    texto_traducido = ""
    translator = Translator()
    for fragmento in fragmentos:
        traduccion = translator.translate(fragmento, src='es', dest='en')
        texto_traducido += traduccion.text
    return texto_traducido

#PARTE 1: Pre-Procesado: poner en minuscula, quitar stop words (tanto español como inglés), crear mi propio vocabulario. Pre-entreno.

# Quita algunas cosillas del texto, entiendo. Clean data cleaning the text of punctuation and special characters. Quita cosas
# output_string = re.sub(pattern, repl, input_string). Coge algunas coasas del texto y pone espacios.
def clean_data(text):
    text = re.sub(r'[^ \nA-Za-z0-9À-ÖØ-öø-ÿ/]+', '', text)
    text = re.sub(r'[\\/×\^\]\[÷]', '', text)
    text = re.sub("\d", '', text)
    text = re.sub("since", '', text)
    text = re.sub("one", '', text)
    text = re.sub("also", '', text)
    text = re.sub("de", '', text)
    text = re.sub("two", '', text)
    text = re.sub("still", '', text)
    text = re.sub("already", '', text)
    text = re.sub("link", '', text)
    text = re.sub("erc", '', text)
    text = re.sub("borr", '', text)
    text = re.sub("monte", '', text)
    text = re.sub("take", '', text)
    text = re.sub("ppisbn", '', text)
    text = re.sub("ibero", '', text)
    text = re.sub("marta", '', text)
    text = re.sub("key", '', text)
    text = re.sub("carmen", '', text)
    text = re.sub("león", '', text)
    text = re.sub("leonardo", '', text)
    text = re.sub("valladolid", '', text)
    text = re.sub("daniel", '', text)
    text = re.sub("ath", '', text)
    text = re.sub("burgos", '', text)
    text = re.sub("navarra", '', text)
    text = re.sub("ardo", '', text)
    text = re.sub("teresa", '', text)
    text = re.sub("mata", '', text)
    text = re.sub("lete", '', text)
    text = re.sub("iii", '', text)
    return text

#Poner en minúsula
def change_lower(text):
    text = text.lower() #simplemente quita las mayúsculas
    return text

#stopwords español
stopwords_list = stopwords.words("spanish")
def remover(text):
    text_tokens = text.split(" ") #aquí separa por bloques cuando vea un espacio. Palabra por palabra
    final_list = [word for word in text_tokens if not word in stopwords_list] # Crea un nuevo objeto que contenga todas las palabras de antes, pero si esa coincide con una stopword, la quita.
    text = ' '.join(final_list)
    return text

#stopwords inglés.
stopwords_list2 = stopwords.words("english")

def remover2(text):
    text_tokens = text.split(" ")
    final_list = [word for word in text_tokens if not word in stopwords_list2] #lo mismo en inglés.
    text = ' '.join(final_list)
    return text


def get_w2vdf(df):
    w2v_df = pd.DataFrame(df['Biografía']).values.tolist()
    for i in range(len(w2v_df)):
        w2v_df[i] = w2v_df[i][0].split(" ")
    return w2v_df

#Se crea el vocabulario (palabras más similares, o sumer y restar vectores...)
def train_w2v(w2v_df):
    cores = multiprocessing.cpu_count()
    w2v_model = Word2Vec(min_count=4,
                         window=4,
                         alpha=0.03,
                         min_alpha=0.0007,
                         sg = 1,
                         workers=cores-1)

    w2v_model.build_vocab(w2v_df, progress_per=10000)
    w2v_model.train(w2v_df, total_examples=w2v_model.corpus_count, epochs=100, report_delay=1)
    return w2v_model



#PARTE 2: LEMATIZACIÓN: Coger las palabras, mirar de qué lema provienen, y eliminar palabras que vengan de la misma raíz. ESTO DEBE SER EN INGLÉS.


def lemmatize_text(text):

    tokens = word_tokenize(text)

    # Inicializar lemmatizador de palabras
    lemmatizer = WordNetLemmatizer()

    # Lematizar cada palabra y agregarla a una lista
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Unir las palabras lematizadas en un string nuevamente
    lemmatized_text = ' '.join(lemmatized_tokens)

    return lemmatized_text

def eliminar_palabras_con_mismo_lema(text):

    lemmatized_text = lemmatize_text(text)

    # Convertir el texto lematizado en una lista de palabras
    palabras = lemmatized_text.split()

    # Eliminar palabras duplicadas
    palabras_sin_duplicados = list(set(palabras))

    # Unir las palabras sin duplicados en un string nuevamente
    texto_sin_duplicados = ' '.join(palabras_sin_duplicados)

    return texto_sin_duplicados


#PARTE 3: ANÁLISIS DE LOS DATOS.

#3.1: WORDCLOUD: Pone en un tipo de gráfica las palabras que más salen en un texto.


def generar_wordcloud(text, titulo):
    wordcloud = WordCloud(max_words = 30,width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(titulo)
    plt.axis('off')
    plt.show()

#3.2 Esto sirve para mirar la frecuencia de las palabras en el texto. Luego me las ordena todas por frecuencias

def contar_frecuencia(text):
    # Dividir el texto en palabras
    palabras = text.split()

    # Crear un diccionario para almacenar la frecuencia de cada palabra
    frecuencia = {}

    # Iterar sobre cada palabra en el texto
    for palabra in palabras:
        # Si la palabra ya está en el diccionario, aumentar su frecuencia en 1
        if palabra in frecuencia:
            frecuencia[palabra] += 1
        # Si la palabra no está en el diccionario, inicializar su frecuencia en 1
        else:
            frecuencia[palabra] = 1

    return frecuencia


#Las ordeno por frecuencia.

def ordenar_por_frecuencia(text):
    # Obtener la frecuencia de cada palabra
    frecuencia_palabras = contar_frecuencia(text)

    # Ordenar las palabras por frecuencia (de mayor a menor)
    palabras_ordenadas = sorted(frecuencia_palabras, key=lambda palabra: frecuencia_palabras[palabra], reverse=True)

    return palabras_ordenadas

# 3.3 Dibuja histogramas de las frecuencias
#Dibujar histograma
def dibujar_histograma(text,titulo):
    # Obtener la frecuencia de cada palabra
    frecuencia_palabras = contar_frecuencia(text)

    # Ordenar las palabras por frecuencia (de mayor a menor)
    palabras_ordenadas = sorted(frecuencia_palabras, key=lambda palabra: frecuencia_palabras[palabra], reverse=True)

    # Tomar solo las primeras 30 palabras
    palabras_30 = palabras_ordenadas[:30]

    # Obtener las frecuencias y las palabras para el gráfico
    frecuencias = [frecuencia_palabras[palabra] for palabra in palabras_30]
    palabras = palabras_30

    # Crear el gráfico de barras
    plt.figure(figsize=(5, 5))
    plt.bar(palabras, frecuencias, color='skyblue')

    # Añadir etiquetas y título
    plt.xlabel('Palabra')
    plt.ylabel('Frecuencia')
    plt.title(titulo)

    # Rotar las etiquetas del eje x para que sean legibles
    plt.xticks(rotation=45, ha='right')

    # Mostrar el gráfico
    plt.tight_layout()
    plt.show()
#3.4 Aquí compara dos listas de frecuencias y quita las x más repetidas coincidentes en cada texto.
#Quito las primeras 30 palabras que coinciden en el texto

def quitar_coincidencias(text, text1):
    # Dividir los textos en palabras
    palabras_texto1 = text.split()
    palabras_texto2 = text1.split()

    # Contar frecuencia de palabras en cada texto
    frecuencias_texto1 = Counter(palabras_texto1)
    frecuencias_texto2 = Counter(palabras_texto2)

    # Obtener las palabras más frecuentes en cada texto
    palabras_frecuentes_texto1 = [palabra for palabra, frecuencia in frecuencias_texto1.most_common()]
    palabras_frecuentes_texto2 = [palabra for palabra, frecuencia in frecuencias_texto2.most_common()]

    # Encontrar las palabras comunes más frecuentes
    palabras_comunes = set(palabras_frecuentes_texto1[:]).intersection(palabras_frecuentes_texto2[:])

    # Eliminar las palabras comunes más frecuentes
    texto1_sin_coincidencias = ' '.join([palabra for palabra in palabras_texto1 if palabra not in palabras_comunes])
    texto2_sin_coincidencias = ' '.join([palabra for palabra in palabras_texto2 if palabra not in palabras_comunes])

    return texto1_sin_coincidencias, texto2_sin_coincidencias

#va raro
def quitar_palabras(text,tex1):

    #divide el texto en cada palabrita
    text_words = text.split()
    text1_words = text1.split()

    #va por cada palabra del texto, y si coincide, la quita.
    for w in text1_words:
      text = text.replace(w, "")

    return text



#¡MIS DATOS!

#Datos de las mujeres.


# Leer el archivo CSV
df = pd.read_csv('/content/DatosTFG_columnas_hombre_mujer.csv')

# Traduzco el texto
df['Biografía'] = df['Biografía'].apply(traducir_texto_largo)



#Aplico a la biografía todas las cosas de pre-procesado.
df[['Biografía']] = df[['Biografía']].astype(str)
df['Biografía'] = df['Biografía'].apply(change_lower)
df['Biografía'] = df['Biografía'].apply(clean_data)
df['Biografía'] = df['Biografía'].apply(remover)
df['Biografía'] = df['Biografía'].apply(remover2)


#lo entreno para tener mi propio vocabulario.
w2v_df = get_w2vdf(df)
w2v_model = train_w2v(w2v_df)


#Lematizo todo.

df['Biografía'] = df['Biografía'].apply(eliminar_palabras_con_mismo_lema)

#lo junto todo en un string.
text = ' '.join(df['Biografía'])


#Crear lista con palabras más frecuentes en las biografías.

frecuencia_palabras = contar_frecuencia(text)
palabras_ordenadas = ordenar_por_frecuencia(text)
print(palabras_ordenadas)
print(frecuencia_palabras)







#CASO HOMBRES, COPIAR Y PEGAR


#Leo el archivo y lo paso a formado pandas, leíble y trabajable.
csv_path1 = '../content/DatosTFG_hombre.csv'
df1 = pd.read_csv(csv_path1)

#ya tengo las funciones puestas arriba, las uso

df1['Biografía'] = df1['Biografía'].apply(traducir_texto_largo)


df1[['Biografía']] = df1[['Biografía']].astype(str)
df1['Biografía'] = df1['Biografía'].apply(change_lower)
df1['Biografía'] = df1['Biografía'].apply(clean_data)
df1['Biografía'] = df1['Biografía'].apply(remover2)
df1['Biografía'] = df1['Biografía'].apply(remover)
df1['Biografía'] = df1['Biografía'].apply(eliminar_palabras_con_mismo_lema)

#Creo mi propio vocabulario entrenado.
w2v_df1 = get_w2vdf(df1)
w2v_model1 = train_w2v(w2v_df1)

#Lo junto en uno
text1 = ' '.join(df1['Biografía'])


#CASO DATOS TOTALES:

#Leo el archivo y lo paso a formado pandas, leíble y trabajable.
csv_path2 = '../content/DatosTFG.csv'
df2 = pd.read_csv(csv_path2)

#ya tengo las funciones puestas arriba, las uso

df2['Biografía'] = df2['Biografía'].apply(traducir_texto_largo)


df2[['Biografía']] = df2[['Biografía']].astype(str)
df2['Biografía'] = df2['Biografía'].apply(change_lower)
df2['Biografía'] = df2['Biografía'].apply(clean_data)
df2['Biografía'] = df2['Biografía'].apply(remover2)
df2['Biografía'] = df2['Biografía'].apply(remover)
df2['Biografía'] = df2['Biografía'].apply(eliminar_palabras_con_mismo_lema)

#Creo mi propio vocabulario entrenado.
w2v_df2 = get_w2vdf(df2)
w2v_model2 = train_w2v(w2v_df2)

#Lo junto en uno
text2 = ' '.join(df2['Biografía'])


#Frecuencias

palabras_ordenadas = ordenar_por_frecuencia(text1)
frecuencia_palabras = contar_frecuencia(text1)
print(palabras_ordenadas)
print(frecuencia_palabras)



texto1_sin_coincidencias, texto2_sin_coincidencias = quitar_coincidencias(text, text1)

print("Texto 1 sin las palabras coincidentes")
print(texto1_sin_coincidencias)

print("\nTexto 2 sin las palabras coincidentes")
print(texto2_sin_coincidencias)


# Generar Word Cloud para el Texto 1
generar_wordcloud(texto1_sin_coincidencias, "Word Cloud de las biografías de las Mujeres")

# Generar Word Cloud para el Texto 2
generar_wordcloud(texto2_sin_coincidencias, "Word Cloud de las biografías de los Hombres")

# Generar Word Cloud para el Texto 1
generar_wordcloud(text, "Word Cloud de las biografías de las Mujeres con las coincidencias")

# Generar Word Cloud para el Texto 2
generar_wordcloud(text1, "Word Cloud de las biografías de los Hombres con las coincidencias")



#Dibujar histograma SIN las primeras 30 palabras coincidentes

titulo = "Mujeres"
titulo1 = "Hombres"
dibujar_histograma(texto1_sin_coincidencias,titulo)
dibujar_histograma(texto2_sin_coincidencias,titulo1)

#Dibujar histograma CON las palabras coincidentes

dibujar_histograma(text,titulo)
dibujar_histograma(text1,titulo1)



#ANALISIS DE SENTIMIENTOS

#Iré metiendo cosillas.

#A ver qué sale

print('Las palabras más parecidas de woman')
a = w2v_model2.wv.most_similar(positive=["woman"])
print(a)

b = w2v_model2.wv.similarity('woman', 'husband')


print(b)


print('Las palabras más parecidas de man')
w2v_model2.wv.most_similar(positive=["man"])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ['university', 'research', 'spanish', 'work', 'scientific', 'professor', 'study', 'science', 'institute', 'year', 'researcher', 'award', 'partment', 'woman', 'director', 'thesis', 'publication', 'first', 'society', 'doctoral', 'national', 'council', 'international', 'member', 'group', 'center', 'madrid', 'field', 'presint', 'project', 'velopment', 'vice', 'gree', 'scientist', 'obtained', 'doctorate', 'association', 'doctor', 'graduated', 'biology', 'spain', 'magazine', 'career', 'new', 'higher', 'various', 'prize', 'published', 'csic', 'part', 'faculty', 'acamy', 'area', 'technology', 'school', 'received', 'acamic', 'state', 'royal', 'began', 'article', 'book', 'recognized', 'dicated', 'life', 'board', 'directed', 'foundation', 'specialized', 'recognition', 'worked', 'participated', 'teaching', 'position', 'professional', 'role', 'among', 'european', 'molecular', 'world', 'system', 'carried', 'medicine', 'scholarship', 'currently', 'program', 'committee', 'well', 'united', 'activity', 'co', 'general', 'author', 'disease', 'line', 'postdoctoral', 'addition', 'dr', 'maría', 'unr', 'application', 'appointed', 'honor', 'medal', 'end', 'chair', 'trajectory', 'laboratory', 'barcelona', 'cell', 'chemistry', 'complutense', 'process', 'l', 'teacher', 'commission', 'within', 'together', 'working', 'santiago', 'chemical', 'later', 'time', 'studied', 'direction', 'autonomous', 'human', 'focused', 'environmental', 'different', 'company', 'social', 'management', 'related', 'biological', 'use', 'master', 'history', 'section', 'natural', 'pharmacy', 'effect', 'granted', 'result', 'created', 'applied', 'technological', 'associated', 'service', 'conference', 'education', 'health', 'knowledge', 'found', 'josé', 'compostela', 'training', 'mainly', 'stay', 'physic', 'several', 'dissemination', 'organization', 'focus', 'analysis', 'numerous', 'ministry', 'january', 'technical', 'stunt', 'april', 'engineering', 'level', 'head', 'expert', 'method', 'continued', 'x', 'born', 'ed', 'isbn', 'responsible', 'cancer', 'based', 'biography', 'number', 'coordinator', 'veloped', 'important', 'congress', 'innovation', 'city', 'mechanism', 'public', 'evaluation', 'p', 'th', 'valencia', 'collaboration', 'institution', 'medical', 'product', 'impact', 'merit', 'present', 'held', 'community', 'course', 'catalan', 'central', 'young', 'data', 'contribution', 'consired', 'pier', 'agency', 'relationship', 'moved', 'support', 'government', 'advisory', 'name', 'founr', 'nerk', 'treatment', 'especially', 'computer', 'june', 'journal', 'action', 'issue', 'family', 'pp', 'clinical', 'subject', 'physical', 'studying', 'great', 'became', 'current', 'editorial', 'edition', 'culture', 'three', 'control', 'official', 'experimental', 'title', 'granada', 'biomedical', 'environment', 'entitled', 'special', 'specialist', 'innovative', 'november', 'conducted', 'polytechnic', 'people', 'collaborated', 'union', 'type', 'aging', 'reference', 'interaction', 'attached', 'alonso', 'protein', 'although', 'known', 'could', 'civil', 'best', 'daughter', 'technique', 'collaborator', 'editor', 'catalonia', 'six', 'specie', 'distinction', 'element', 'main', 'organized', 'galicia', 'extraordinary', 'museum', 'art', 'fernánz', 'third', 'led', 'ochoa', 'cember', 'severo', 'belonging', 'joined', 'returned', 'return', 'madridin', 'team', 'biochemistry', 'married', 'presented', 'many', 'patient', 'alzheimers', 'outstanding', 'vol', 'presence', 'following', 'basic', 'commitment', 'american', 'kingdom', 'chapter', 'artificial', 'excellence', 'strategy', 'hundred', 'framework', 'non', 'promote', 'diagnosis', 'juan', 'therapeutic', 'english', 'gene', 'gonzález', 'online', 'specializing', 'investigation', 'four', 'cause', 'due', 'place', 'economic', 'problem', 'gold', 'attend', 'material', 'meeting', 'high', 'war', 'industrial', 'miguel', 'review', 'educational', 'long', 'ramón', 'table', 'right', 'last', 'july', 'specifically', 'importance', 'corresponding', 'directs', 'secretary', 'change', 'large', 'local ...
# {'center': 27, 'disease': 15, 'investigated': 5, 'biology': 22, 'birmingham': 1, 'ochoa': 6, 'cember': 6, 'severo': 6, 'line': 15, 'belonging': 6, 'physiology': 5, 'uam': 3, 'childrenresearch': 1, 'vision': 2, 'university': 64, 'research': 59, 'joined': 6, 'named': 2, 'glycinergic': 1, 'professor': 46, 'partment': 33, 'compd': 5, 'relationship': 8, 'shortly': 1, 'direction': 12, 'universityand': 1, 'titular': 4, 'returned': 6, 'work': 48, 'postdoctoral': 15, 'institute': 41, 'trainingupon': 1, 'major': 2, 'neuromuscular': 1, 'granada': 7, 'access': 4, 'moved': 8, 'nervous': 3, 'council': 29, 'molecular': 16, 'higher': 21, 'world': 16, 'return': 6, 'madrid': 26, 'set': 5, 'researchin': 1, 'madridin': 6, 'addition': 15, 'schizophrenia': 1, 'base': 5, 'team': 6, 'universityfrom': 2, 'zaragozafrom': 1, 'interested': 4, 'scientific': 47, 'specified': 1, 'spain': 22, 'gree': 25, 'obtained': 23, 'biochemistry': 6, 'system': 16, 'officebut': 1, 'functioning': 1, 'researcherhe': 3, 'pharmacy': 11, 'field': 26, 'autonomous': 12, 'faculty': 20, 'position': 17, 'married': 6, 'neurotransmissionin': 1, 'phd': 5, 'end': 14, 'acute': 4, 'biomedical': 7, 'planact': 1, 'agriculture': 5, 'intensify': 1, 'multidisciplinary': 2, 'administration': 5, 'international': 29, 'electrician': 1, 'dr': 15, 'exchange': 5, 'plan': 5, 'various': 21, 'consolidated': 1, 'good': 5, 'luis': 5, 'rectorate': 1, 'human': 12, 'pologies': 5, 'actorsthe': 1, 'contributed': 3, 'presented': 6, 'fellow': 5, 'initiator': 1, 'projectsamong': 1, 'focused': 12, 'self': 1, 'chair': 14, 'maría': 15, 'life': 18, 'generated': 1, 'agenciesin': 1, 'agreement': 2, 'effect': 11, 'eliciation': 1, 'house': 3, 'transforming': 1, 'allows': 3, 'l': 13, 'investigating': 4, 'environmental': 12, 'electronic': 4, 'configures': 1, 'many': 6, 'qdictated': 1, 'missing': 1, 'wireless': 1, 'professional': 17, 'cancerneurology': 1, 'olr': 2, 'unr': 15, 'nobel': 5, 'patient': 6, 'wearable': 1, 'simple': 1, 'mr': 4, 'greece': 1, 'collaborates': 5, 'rehabilitation': 1, 'conferencesparticipated': 1, 'wi': 3, 'role': 17, 'diabetic': 1, 'contextthese': 1, 'board': 18, 'spanish': 58, 'dkv': 1, 'extensive': 3, 'prevent': 4, 'acamicscientific': 1, 'carried': 16, 'environment': 7, 'lifespace': 1, 'support': 8, 'ata': 1, 'companyhe': 1, 'forum': 4, 'proceeding': 3, 'prize': 21, 'america': 3, 'government': 8, 'niería': 1, 'different': 12, 'coordinator': 9, 'medtronic': 1, 'post': 2, 'publication': 31, 'prima': 1, 'medicine': 16, 'doctorate': 23, 'smartex': 1, 'healthy': 3, 'safety': 2, 'velops': 2, 'teacher': 13, 'numerous': 10, 'veloped': 9, 'member': 29, 'accessibility': 1, 'formation': 4, 'advisory': 8, 'including': 5, 'casessign': 1, 'company': 12, 'ingebiomedical': 1, 'article': 19, 'supporting': 2, 'social': 12, 'novartis': 1, 'respond': 3, 'diseasesin': 1, 'entity': 3, 'inclusion': 2, 'scholarship': 16, 'sabi': 2, 'projectacamic': 1, 'better': 2, 'inpennt': 3, 'healthand': 1, 'lifestech': 1, 'segura': 1, 'diabetes': 3, 'parkinson': 3, 'remote': 1, 'isap': 1, 'book': 19, 'enhanced': 1, 'granted': 11, 'societyresearch': 1, 'platform': 2, 'houssay': 1, 'prominent': 3, 'nerkputy': 1, 'spainhe': 3, 'entitled': 7, 'internationally': 3, 'flag': 1, 'moling': 5, 'acamy': 20, 'livinglabsin': 1, 'leading': 3, 'name': 8, 'integrated': 2, 'home': 1, 'unique': 1, 'neurological': 1, 'signal': 2, 'promotion': 1, 'theinpennt': 1, 'bern': 1, 'figure': 1, 'monitoring': 4, 'ministry': 10, 'first': 30, 'sign': 2, 'technologiessmart': 1, 'symposium': 4, 'throughout': 5, 'cognitive': 2, 'daily': 2, 'currently': 16, 'london': 3, 'special': 7, 'sciencedirector': 1, 'vodaf': 1, 'sector': 5, 'association': 23, 'maria': 3, 'significant': 1, 'important': 9, 'specialist': 7, 'user': 1, 'researchersandor': 1, 'ip': 1, 'alzheimers': 6, 'paradigm': 2, 'renewal': 2, 'drug': 4, 'coronary': 2, 'york': 4, 'program': 16, 'industry': 4, 'directed': 18, 'workbiography': 2, 'sexenciesmaría': 1, 'ipneuronal': 1, 'performing': 2, 'result': 11, ' ...
# ['university', 'research', 'professor', 'spanish', 'scientific', 'science', 'study', 'director', 'national', 'member', 'award', 'work', 'institute', 'doctor', 'center', 'prize', 'published', 'article', 'researcher', 'international', 'received', 'doctorate', 'new', 'year', 'partment', 'european', 'society', 'council', 'first', 'madrid', 'scientist', 'american', 'field', 'publication', 'medicine', 'group', 'united', 'school', 'magazine', 'spain', 'career', 'book', 'health', 'well', 'acamy', 'causa', 'honoris', 'foundation', 'project', 'state', 'among', 'worked', 'world', 'faculty', 'author', 'presint', 'area', 'thesis', 'doctoral', 'addition', 'velopment', 'numerous', 'royal', 'jaime', 'graduated', 'born', 'postdoctoral', 'barcelona', 'contribution', 'various', 'biology', 'category', 'training', 'appointed', 'acamic', 'molecular', 'collaboration', 'honor', 'studied', 'higher', 'education', 'cited', 'association', 'professional', 'outstanding', 'medical', 'hospital', 'recognition', 'san', 'obtained', 'technology', 'participated', 'later', 'program', 'dr', 'chemical', 'currently', 'five', 'activity', 'began', 'high', 'several', 'granted', 'recognized', 'laboratory', 'process', 'technical', 'king', 'committee', 'position', 'gree', 'disease', 'biomedical', 'l', 'team', 'medal', 'part', 'distinguished', 'direction', 'innovation', 'physical', 'institution', 'valencia', 'vice', 'physic', 'different', 'veloped', 'chemistry', 'chapter', 'journal', 'head', 'orr', 'biography', 'complutense', 'ministry', 'subject', 'great', 'life', 'government', 'cancer', 'best', 'time', 'dissemination', 'review', 'country', 'excellence', 'advanced', 'application', 'polytechnic', 'working', 'csic', 'moved', 'grant', 'stay', 'focus', 'focused', 'directed', 'co', 'natural', 'juan', 'scholarship', 'sport', 'gonzález', 'technique', 'dicated', 'college', 'basic', 'engineering', 'management', 'isbn', 'environment', 'communication', 'j', 'system', 'impact', 'merit', 'creation', 'following', 'together', 'june', 'chair', 'analysis', 'unr', 'march', 'autonomous', 'created', 'carried', 'mechanism', 'division', 'distinction', 'investigation', 'according', 'clinical', 'art', 'applied', 'known', 'held', 'service', 'specialized', 'carlos', 'level', 'taught', 'rey', 'ed', 'congress', 'conference', 'interaction', 'board', 'may', 'january', 'city', 'honorary', 'miguel', 'unit', 'josé', 'teacher', 'r', 'internationally', 'culture', 'special', 'york', 'main', 'based', 'editor', 'gene', 'effect', 'important', 'organization', 'public', 'knowledge', 'asturias', 'many', 'british', 'harvard', 'stunt', 'others', 'large', 'specialist', 'today', 'specialty', 'c', 'place', 'human', 'medium', 'throughout', 'change', 'master', 'industry', 'use', 'quality', 'engineer', 'social', 'future', 'information', 'technological', 'bbva', 'trajectory', 'quantum', 'return', 'formation', 'written', 'sign', 'cruz', 'within', 'material', 'appointment', 'granada', 'germany', 'structure', 'led', 'initiative', 'disseminator', 'became', 'related', 'newspaper', 'hundred', 'computer', 'theoretical', 'last', 'issue', 'line', 'directs', 'editorial', 'physicist', 'blog', 'civil', 'advisory', 'h', 'direct', 'cember', 'interest', 'nature', 'name', 'selection', 'gran', 'cell', 'treatment', 'catalonia', 'writer', 'april', 'chosen', 'took', 'paris', 'hernánz', 'digital', 'non', 'official', 'basque', 'company', 'general', 'four', 'nerks', 'governing', 'coordinator', 'prestigious', 'food', 'returned', 'ofthe', 'teaching', 'valencian', 'greatest', 'pharmacy', 'x', 'santiago', 'complex', 'promotion', 'twenty', 'aspect', 'way', 'discovery', 'collaborated', 'informative', 'discovered', 'salamanca', 'atomic', 'visiting', 'section', 'microbiology', 'patent', 'global', 'early', 'joint', 'collaborator', 'ramón', 'earth', 'selected', 'elected', 'environmental', 'th', 'ecology', 'founr', 'climate', 'died', 'expert', 'october', 'history', 'september', 'gold', 'b', 'europe', 'community', 'data', 'composed', 'prince', 'thirteen', ' ...
# {'well': 17, 'horticulture': 1, 'united': 19, 'professor': 44, 'subject': 9, 'juan': 8, 'work': 31, 'various': 13, 'organized': 4, 'stand': 3, 'studied': 12, 'indicated': 1, 'resis': 1, 'long': 4, 'ashton': 1, 'chemical': 11, 'safe': 3, 'salzburg': 1, 'fullbrighthys': 1, 'gaztelueta': 1, 'researcher': 26, 'varied': 1, 'currently': 11, 'american': 21, 'austriahe': 1, 'many': 6, 'british': 6, 'five': 11, 'thesis': 14, 'harvard': 6, 'higher': 12, 'writer': 5, 'applied': 7, 'yearshe': 1, 'scientific': 42, 'school': 19, 'spanish': 44, 'field': 21, 'publishing': 3, 'stunt': 6, 'education': 12, 'doctoral': 14, 'center': 28, 'prize': 28, 'participate': 2, 'secondary': 3, 'partment': 23, 'published': 27, 'great': 9, 'known': 7, 'station': 2, 'diffusion': 1, 'state': 16, 'friendship': 2, 'bristol': 2, 'study': 35, 'edaphology': 1, 'morality': 1, 'doctor': 30, 'experimental': 1, 'allhe': 1, 'cultural': 3, 'biology': 13, 'scholarship': 8, 'thanks': 2, 'among': 16, 'research': 46, 'university': 48, 'worked': 16, 'biologisthe': 1, 'spiritual': 1, 'cuorniú': 1, 'england': 3, 'received': 24, 'seminar': 2, 'council': 22, 'science': 41, 'bilbaohe': 2, 'admitted': 1, 'essay': 2, 'christian': 1, 'futiculture': 1, 'formed': 2, 'scaniapamplona': 1, 'april': 5, 'gastroenterology': 1, 'right': 2, 'cited': 12, 'francethey': 1, 'occasion': 2, 'international': 26, 'ana': 2, 'chosen': 5, 'junior': 1, 'followed': 2, 'held': 7, 'figure': 1, 'european': 23, 'lau': 1, 'first': 22, 'peculiar': 1, 'virgen': 2, 'native': 1, 'category': 13, 'championship': 1, 'world': 16, 'salto': 1, 'villava': 1, 'life': 9, 'associate': 4, 'letic': 1, 'jumpduring': 1, 'took': 5, 'others': 6, 'gainin': 1, 'service': 7, 'large': 6, 'occupation': 1, 'club': 3, 'collaboratingin': 1, 'l': 10, 'economist': 1, 'rank': 1, 'step': 2, 'othersthis': 1, 'garralda': 1, 'family': 4, 'invented': 1, 'like': 1, 'record': 2, 'getting': 2, 'jumpchildhood': 1, 'association': 12, 'french': 2, 'specialist': 6, 'reaching': 1, 'trophy': 1, 'coinciding': 1, 'brand': 2, 'pamplona': 2, 'pylorus': 1, 'paris': 5, 'scarcity': 1, 'professional': 12, 'subsequently': 4, 'camino': 1, 'hernánz': 5, 'chief': 2, 'dicates': 1, 'height': 1, 'finitively': 2, 'contestin': 1, 'top': 1, 'letics': 1, 'youth': 2, 'beingdoctor': 1, 'helicobacter': 1, 'highlight': 2, 'injury': 1, 'specialized': 7, 'magazine': 19, 'outstanding': 12, 'team': 10, 'navarrese': 1, 'lawyer': 1, 'amounted': 1, 'played': 1, 'achieved': 4, 'fernando': 3, 'clinicafter': 1, 'today': 6, 'portland': 1, 'mateo': 2, 'caun': 1, 'medical': 12, 'handball': 1, 'neglect': 1, 'activity': 11, 'began': 11, 'amateur': 1, 'hospital': 12, 'dick': 1, 'carlos': 7, 'government': 9, 'sport': 8, 'opposition': 1, 'pology': 4, 'medal': 10, 'training': 13, 'national': 33, 'recognition': 12, 'child': 4, 'navarro': 2, 'bronze': 1, 'publication': 21, 'feat': 1, 'laua': 1, 'historic': 1, 'iturri': 1, 'munich': 1, 'maximum': 2, 'caunand': 1, 'san': 12, 'medicine': 21, 'doctorate': 24, 'pamplonahe': 1, 'jump': 1, 'olympics': 1, 'champion': 1, 'madrid': 22, 'town': 2, 'fosbury': 1, 'addition': 14, 'high': 11, 'member': 32, 'obtained': 12, 'digestive': 1, 'colon': 1, 'reason': 2, 'test': 1, 'foral': 1, 'ile': 1, 'faculty': 16, 'antonio': 4, 'receiving': 1, 'article': 27, 'stood': 3, 'daughter': 2, 'personal': 4, 'specialty': 6, 'share': 2, 'competition': 2, 'initiating': 1, 'sportdoctor': 1, 'serious': 1, 'conducted': 4, 'cancer': 9, 'borda': 2, 'cum': 1, 'best': 9, 'atlético': 1, 'part': 10, 'roller': 1, 'knee': 1, 'tartan': 1, 'titlesmeanwhile': 1, 'plaza': 3, 'captain': 2, 'several': 11, 'gonzález': 8, 'miguelinduráin': 1, 'granted': 11, 'highlighting': 1, 'exatleta': 1, 'award': 32, 'surgery': 4, 'technique': 8, 'si': 1, 'cycling': 1, 'passing': 3, 'cyclist': 1, 'dorsal': 1, 'movedsports': 1, 'spain': 19, 'time': 9, 'dicated': 8, 'heightit': 1, 'distinguished': 10, 'style': 1, 'beat': 1, 'silver': 2, 'founding': 3, 'six': 3, 'intelligent': 2, 'classroomaeronautics': 1, 'product ...
# Texto 1 sin las palabras coincidentes
# birmingham childrenresearch named glycinergic universityand trainingupon major neuromuscular nervous researchin schizophrenia zaragozafrom specified officebut researcherhe married neurotransmissionin planact intensify multidisciplinary electrician good rectorate pologies actorsthe initiator projectsamong generated agenciesin eliciation transforming allows configures qdictated missing wireless cancerneurology wearable rehabilitation conferencesparticipated wi diabetic contextthese dkv extensive prevent acamicscientific lifespace ata companyhe proceeding niería medtronic prima smartex safety accessibility casessign ingebiomedical novartis respond diseasesin entity inclusion sabi projectacamic healthand lifestech segura parkinson isap societyresearch houssay prominent nerkputy flag livinglabsin leading signal theinpennt bern technologiessmart sciencedirector vodaf maria researchersandor ip alzheimers renewal workbiography sexenciesmaría ipneuronal telemedicine stroke apraxiaendocrinology panvitapharmacology argentinasubsequently implementation withnumerous technologiescoordinator scenario etcfacilitate predict comp telemedicina electric ihealth comply manyothersit samsung pre madridmobihealth respiratory markedly periscope automotic infoaccessibility nyas lifehe etsitupmadvisor patientsactive dilated lst healthcareth en arredondo assisted lifehis dresv need aha facebook requirement luminotechnics pologiesoncology microsoft fibrillation philip transventricular rectorateof thesespublished researchshe socio sensor peoplethis threshold implemented specification multiformat engineerig textile etsit healthin campusmerit cao leloir fieldthe mobile unionhis repussion needshe pulse conditionshis spectrum involvedthe discharge fibrillatory upmthe livinglabs qualified broad inpennce transaction brilliant bioengineering torressee cision enhancing argentinain cortical expand yearsshe tucumán introduced moncloa occlusioncourt upmrobotics dressed automatic puzzle psychologiststhe seib vojext foglia eit ischemia type lifestylepsychiatry ehealth hygiene activage pub iot imserso ahp servicesto societydirector woman healthcare interactive theseshe neuronal ahpin orientation throughouttheir barcelonacovid spainin americadirector waldmeyer accessible failure pharmaledger lifein magnifico promote located needshigher sept universal nokia follow microelectronic pilot careeraward instrumental isahp signer pe domotized imi multicentric resuscitation postrecruitment argentine prolific painted proteomic good castilian llorente endothelial vicenta hypoxia rosuvastatina martorell vascular smooth lesion maestro apoptosis garcíaarguinzonis cellsclinic societyfor serum cubedo myocardial paula tpadró sala premature moll infarcionclinic spectrumspanish acronym copy castellano costales receptor aledo judith statin badimon lluís polymorphism hypholesterolemiaspanish arteriosclerosishe lrp cristina rosuvastatin transcription orphan cardiac neuronrned barceloanfor sendra lina maisa prevents hifa gemma extra covered proteome initiatedhe low receiver lipoproteinsclinic crespo muscle cholesterol stimulates benefit researchclinical physiologist vilahurclinical cinca rodrigo esci diseasebiography mapping absence recently susceptibility age amyloid inheritance bound variation play sergievsky barral spainunfortunately barié late cumc increasing alzheimers alzheimertherapeutic veteran disorrsaccording convincing sporadic bleak cidhe however gertru worsens thecolumbia taub suggest preseniline neurogenerative leap ailment neurogenetic allele pessimism abandoning comply precursor diseasethe lareu evince think velopmentthe onset diseaseit preventivethrough apolipoprotein expectation professionthis etiology maza intify bruker trustee germanyduring juanas godferafter badge catalán oil sedo recently exam abbé totally urinary recognitionministry microorganism moral reunion anque met sirold calatravere sectorshe manchego beer spectroscopic comillas woman orientationhe valdés spanishaw ...
#
# Texto 2 sin las palabras coincidentes
# horticulture ashton safe salzburg fullbrighthys gaztelueta varied austriahe harvard diffusion friendship bristol morality allhe spiritual cuorniú futiculture scaniapamplona gastroenterology francethey junior followed lau peculiar virgen native championship salto villava letic jumpduring took gainin collaboratingin economist rank othersthis garralda invented like jumpchildhood reaching trophy coinciding brand pamplona pylorus scarcity camino height finitively contestin letics beingdoctor helicobacter navarrese amounted clinicafter portland mateo caun handball neglect amateur dick feat laua historic iturri munich caunand pamplonahe jump olympics champion town fosbury colon foral ile receiving initiating sportdoctor borda cum atlético roller knee tartan titlesmeanwhile captain miguelinduráin highlighting exatleta si cycling passing cyclist dorsal movedsports heightit style beat classroomaeronautics processing researcherprofessional cim maintenance sciencebusiness ceo tomorrow sectorqualitas correspond mrp interpreter injection sustainability economista experimenting maneditorial icts worth offering systemant systempant skeptical systemsdyna concurrent diario mere existentfor claim entrepreneurhe thermoplastic daysnanoproductsmagazine systemsmro noting systemplant scheduling organizational produce practically plantseditorial protectionism automotiveautomotive moreeditorial technologiesbulletin machine projectsit hodie ifip epened automotive small philosophical etsii computerized okp extinct competitivenessbulletin operate factory repair optimize vvaa competitivenessedicis digitaleditorial caution quantitative habitabilityand borda launch legate revolution cyber andit conceptsapplication datal futurehuman thefactory digitalization create pillar dordrechtjavier multinational itfor elejabarrieta educationhe quevedo ecoc appreciable speed crease cost broadband forimprove physicsfoundation osa particularly valenciainvestigate capmany iteam awf systemscapmany photonic iethe replacing housewifewhen consistoryearly paloma sublegation socialist win xix rebollar coiaclche stewardship politician greewithin happens prison polanco armed homeland satisfied lost vowel palenciaas imparting madridthen universityluis writes fallen internationalfor lxv medrano countrysi signand ensign hiring treasury sergio finance nicolás plenary pure viticulture areaof ortega engineerdoctor areatogether winegovernment yearsagricultural noted mariosimón councilor palenciaon yutero provincehe victory goal easter requenaof lieutenant ofthis machinery approval requenait girviten absent projecting agriculturehis magazinesin positionin uvaprofessional ac ofagronomic bioprocess winery currentlyit gutiérrez careerafter councilors possession military half maintenance commissionnavalrecognitions leaving election oenology cárcel took nationally requena vitiviniculture asnumber corporation upvhe satragsa machine party villagehe requean transferred nerkhe citizen join miriam vitivinícola monday enoologythe gutiérrezas ramiro let arsenal office legate assured hard income paradoxically sublegate affirming honored cyted majority ace sciencebusiness absolute profionion enology legated butler leaf palencia rectorit cityin frigate palenciafinally behind aula vote happening femp purple navyfirst seat oenological bari luismiguel contracting enoological holy enriching andrésalthough engineeringagrarian ensuring vast uvamox therereturn xth wissenschaftliches meetingsboth sponsountil magazinedistinctions zeitschrift housemember advancement aforementid tubinga graphic française gesellschaft biennial allgemeine joachim sagrario latinamerican inorganic purposein utscher facultyteaching crystallógraphic ditiooxamis anorganische strähle marburg chemiker agreed magazinemember wissenschaftlicher chemistryphysics tübingen spanishiallian hiller attachment diffraction polyhedron ntistry monochristal cristlolelgraphie compostelaat wolfgang arbeitsgrupen adduct beiratmember groupsportuguese cloister ...
# Las palabras más parecidas de woman
# [('compound', 0.6870186924934387), ('proliferation', 0.6751746535301208), ('heritage', 0.6617101430892944), ('example', 0.6606930494308472), ('step', 0.6556288003921509), ('case', 0.633259654045105), ('jiménez', 0.632498025894165), ('twenty', 0.6233328580856323), ('pablo', 0.6218765377998352), ('relation', 0.6213558316230774)]
# 0.56072545
# Las palabras más parecidas de man
# [('transmission', 0.8815538883209229),
#  ('plan', 0.8359972238540649),
#  ('title', 0.8358909487724304),
#  ('good', 0.8264586925506592),
#  ('occasion', 0.8235754370689392),
#  ('exchange', 0.817554771900177),
#  ('rocasolano', 0.8132659196853638),
#  ('response', 0.8049581050872803),
#  ('disciple', 0.8022798895835876),
#  ('promotion', 0.7992211580276489)]
