# %% [markdown]
# <a href="https://colab.research.google.com/github/Sashka1101/TFG_Gender_Bias/blob/main/ESTE_ES_EL_BUENO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
pip install matplot
# Out:
# Collecting matplot
#   Downloading matplot-0.1.9-py2.py3-none-any.whl (5.0 kB)
# Collecting pyloco>=0.0.134 (from matplot)
#   Downloading pyloco-0.0.139-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from matplot) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->matplot) (2.8.2)
# Collecting ushlex (from pyloco>=0.0.134->matplot)
#   Downloading ushlex-0.99.1.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from pyloco>=0.0.134->matplot) (1.7.0)
# Collecting twine (from pyloco>=0.0.134->matplot)
#   Downloading twine-5.0.0-py3-none-any.whl (37 kB)
# Collecting typing (from pyloco>=0.0.134->matplot)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting SimpleWebSocketServer (from pyloco>=0.0.134->matplot)
#   Downloading SimpleWebSocketServer-0.1.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.16.0)
# Collecting pkginfo>=1.8.1 (from twine->pyloco>=0.0.134->matplot)
#   Downloading pkginfo-1.10.0-py3-none-any.whl (30 kB)
# Collecting readme-renderer>=35.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading readme_renderer-43.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from twine->pyloco>=0.0.134->matplot) (2.31.0)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from twine->pyloco>=0.0.134->matplot) (2.0.7)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.10/dist-packages (from twine->pyloco>=0.0.134->matplot) (7.0.2)
# Requirement already satisfied: keyring>=15.1 in /usr/lib/python3/dist-packages (from twine->pyloco>=0.0.134->matplot) (23.5.0)
# Collecting rfc3986>=1.4.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from twine->pyloco>=0.0.134->matplot) (13.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=3.6->twine->pyloco>=0.0.134->matplot) (3.17.0)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading nh3-0.2.15-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: docutils>=0.13.1 in /usr/local/lib/python3.10/dist-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.18.1)
# Requirement already satisfied: Pygments>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.16.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.2)
# Building wheels for collected packages: SimpleWebSocketServer, typing, ushlex
#   Building wheel for SimpleWebSocketServer (setup.py) ... done
#   Created wheel for SimpleWebSocketServer: filename=SimpleWebSocketServer-0.1.2-py3-none-any.whl size=9664 sha256=e4057ab7e96e43e77dd90f23c49974d6f08a476167c7b75d5b82d02cffc47991
#   Stored in directory: /root/.cache/pip/wheels/af/cb/9d/23ef01c9c26b978be6d29ed456d7348abd0e96b1563049bd63
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26304 sha256=34cb00cd2658d54828f4c2e3eb5f0e2eb1c07bd5b8560c69a3c40a5ea7d7dbda
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
#   Building wheel for ushlex (setup.py) ... done
#   Created wheel for ushlex: filename=ushlex-0.99.1-py3-none-any.whl size=4394 sha256=10fc4bf5c7e89f3100169e9e19e57ae96bdaa776446829efa50e1cff38d71dbe
#   Stored in directory: /root/.cache/pip/wheels/fd/e4/80/4de44668798392eb2f5b24f0130df2f5d28b43cb256bf9c1f9
# Successfully built SimpleWebSocketServer typing ushlex
# Installing collected packages: ushlex, SimpleWebSocketServer, nh3, typing, rfc3986, readme-renderer, pkginfo, requests-toolbelt, twine, pyloco, matplot
# Successfully installed SimpleWebSocketServer-0.1.2 matplot-0.1.9 nh3-0.2.15 pkginfo-1.10.0 pyloco-0.0.139 readme-renderer-43.0 requests-toolbelt-1.0.0 rfc3986-2.0.0 twine-5.0.0 typing-3.7.4.3 ushlex-0.99.1

# %%
pip install Word2Vec
# Out:
# Collecting Word2Vec
#   Downloading word2vec-0.11.1.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 843.2 kB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from Word2Vec) (1.25.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from Word2Vec) (1.3.2)
# Building wheels for collected packages: Word2Vec
#   Building wheel for Word2Vec (pyproject.toml) ... done
#   Created wheel for Word2Vec: filename=word2vec-0.11.1-py2.py3-none-any.whl size=141242 sha256=65e9e0497efd7532b6d11bef42014f5b17d9374d4a943e6b1cfbaa903c2e7e64
#   Stored in directory: /root/.cache/pip/wheels/6a/fa/d1/e03e8c10e0e2aa5c7b6e2b46b4a1c715d140283853937bb4b1
# Successfully built Word2Vec
# Installing collected packages: Word2Vec
# Successfully installed Word2Vec-0.11.1

# %%
pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.2.2)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.3.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 16.2 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.3 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.8 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.5 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.3 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=0f8fa9c17b4d7f41c6212b142ac1056394a7a5f9a71976c2a2d32206266818ae
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: rfc3986
#     Found existing installation: rfc3986 2.0.0
#     Uninstalling rfc3986-2.0.0:
#       Successfully uninstalled rfc3986-2.0.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.3.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from gensim.models import Word2Vec
import multiprocessing
import nltk
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
import matplotlib.pyplot as plt
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import googletrans
from googletrans import Translator
import csv
from collections import Counter
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download("omw-1.4")


# Función para traducir un texto muy largo
def traducir_texto_largo(texto):
    # Dividir el texto en fragmentos más pequeños para evitar errores
    fragmentos = [texto[i:i+5000] for i in range(0, len(texto), 5000)]
    texto_traducido = ""
    translator = Translator()
    for fragmento in fragmentos:
        traduccion = translator.translate(fragmento, src='es', dest='en')
        texto_traducido += traduccion.text
    return texto_traducido

#PARTE 1: Pre-Procesado: poner en minuscula, quitar stop words (tanto español como inglés), crear mi propio vocabulario. Pre-entreno.

# Quita algunas cosillas del texto, entiendo. Clean data cleaning the text of punctuation and special characters. Quita cosas
# output_string = re.sub(pattern, repl, input_string). Coge algunas coasas del texto y pone espacios.
def clean_data(text):
    text = re.sub(r'[^ \nA-Za-z0-9À-ÖØ-öø-ÿ/]+', '', text)
    text = re.sub(r'[\\/×\^\]\[÷]', '', text)
    text = re.sub("\d", '', text)
    text = re.sub("since", '', text)
    text = re.sub("one", '', text)
    text = re.sub("also", '', text)
    text = re.sub("de", '', text)
    text = re.sub("two", '', text)
    text = re.sub("still", '', text)
    text = re.sub("already", '', text)
    text = re.sub("link", '', text)
    text = re.sub("erc", '', text)
    text = re.sub("borr", '', text)
    text = re.sub("monte", '', text)
    text = re.sub("take", '', text)
    text = re.sub("ppisbn", '', text)
    text = re.sub("ibero", '', text)
    text = re.sub("marta", '', text)
    text = re.sub("key", '', text)
    text = re.sub("carmen", '', text)
    text = re.sub("leon", '', text)
    text = re.sub("leonardo", '', text)
    text = re.sub("valladolid", '', text)
    text = re.sub("daniel", '', text)
    text = re.sub("ath", '', text)
    text = re.sub("brgos", '', text)
    text = re.sub("navarra", '', text)
    return text

#Poner en minúsula
def change_lower(text):
    text = text.lower() #simplemente quita las mayúsculas
    return text

#stopwords español
stopwords_list = stopwords.words("spanish")
def remover(text):
    text_tokens = text.split(" ") #aquí separa por bloques cuando vea un espacio. Palabra por palabra
    final_list = [word for word in text_tokens if not word in stopwords_list] # Crea un nuevo objeto que contenga todas las palabras de antes, pero si esa coincide con una stopword, la quita.
    text = ' '.join(final_list)
    return text

#stopwords inglés.
stopwords_list2 = stopwords.words("english")

def remover2(text):
    text_tokens = text.split(" ")
    final_list = [word for word in text_tokens if not word in stopwords_list2] #lo mismo en inglés.
    text = ' '.join(final_list)
    return text


def get_w2vdf(df):
    w2v_df = pd.DataFrame(df['Biografía']).values.tolist()
    for i in range(len(w2v_df)):
        w2v_df[i] = w2v_df[i][0].split(" ")
    return w2v_df

#Se crea el vocabulario (palabras más similares, o sumer y restar vectores...)
def train_w2v(w2v_df):
    cores = multiprocessing.cpu_count()
    w2v_model = Word2Vec(min_count=4,
                         window=4,
                         alpha=0.03,
                         min_alpha=0.0007,
                         sg = 1,
                         workers=cores-1)

    w2v_model.build_vocab(w2v_df, progress_per=10000)
    w2v_model.train(w2v_df, total_examples=w2v_model.corpus_count, epochs=100, report_delay=1)
    return w2v_model



#PARTE 2: LEMATIZACIÓN: Coger las palabras, mirar de qué lema provienen, y eliminar palabras que vengan de la misma raíz. ESTO DEBE SER EN INGLÉS.


def lemmatize_text(text):

    tokens = word_tokenize(text)

    # Inicializar lemmatizador de palabras
    lemmatizer = WordNetLemmatizer()

    # Lematizar cada palabra y agregarla a una lista
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Unir las palabras lematizadas en un string nuevamente
    lemmatized_text = ' '.join(lemmatized_tokens)

    return lemmatized_text

def eliminar_palabras_con_mismo_lema(text):

    lemmatized_text = lemmatize_text(text)

    # Convertir el texto lematizado en una lista de palabras
    palabras = lemmatized_text.split()

    # Eliminar palabras duplicadas
    palabras_sin_duplicados = list(set(palabras))

    # Unir las palabras sin duplicados en un string nuevamente
    texto_sin_duplicados = ' '.join(palabras_sin_duplicados)

    return texto_sin_duplicados


#PARTE 3: ANÁLISIS DE LOS DATOS.

#3.1: WORDCLOUD: Pone en un tipo de gráfica las palabras que más salen en un texto.


def generar_wordcloud(text, titulo):
    wordcloud = WordCloud(max_words = 15,width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(titulo)
    plt.axis('off')
    plt.show()

#3.2 Esto sirve para mirar la frecuencia de las palabras en el texto. Luego me las ordena todas por frecuencias

def contar_frecuencia(text):
    # Dividir el texto en palabras
    palabras = text.split()

    # Crear un diccionario para almacenar la frecuencia de cada palabra
    frecuencia = {}

    # Iterar sobre cada palabra en el texto
    for palabra in palabras:
        # Si la palabra ya está en el diccionario, aumentar su frecuencia en 1
        if palabra in frecuencia:
            frecuencia[palabra] += 1
        # Si la palabra no está en el diccionario, inicializar su frecuencia en 1
        else:
            frecuencia[palabra] = 1

    return frecuencia


#Las ordeno por frecuencia.

def ordenar_por_frecuencia(text):
    # Obtener la frecuencia de cada palabra
    frecuencia_palabras = contar_frecuencia(text)

    # Ordenar las palabras por frecuencia (de mayor a menor)
    palabras_ordenadas = sorted(frecuencia_palabras, key=lambda palabra: frecuencia_palabras[palabra], reverse=True)

    return palabras_ordenadas

# 3.3 Dibuja histogramas de las frecuencias
#Dibujar histograma
def dibujar_histograma(text,titulo):
    # Obtener la frecuencia de cada palabra
    frecuencia_palabras = contar_frecuencia(text)

    # Ordenar las palabras por frecuencia (de mayor a menor)
    palabras_ordenadas = sorted(frecuencia_palabras, key=lambda palabra: frecuencia_palabras[palabra], reverse=True)

    # Tomar solo las primeras 30 palabras
    palabras_30 = palabras_ordenadas[:30]

    # Obtener las frecuencias y las palabras para el gráfico
    frecuencias = [frecuencia_palabras[palabra] for palabra in palabras_30]
    palabras = palabras_30

    # Crear el gráfico de barras
    plt.figure(figsize=(5, 5))
    plt.bar(palabras, frecuencias, color='skyblue')

    # Añadir etiquetas y título
    plt.xlabel('Palabra')
    plt.ylabel('Frecuencia')
    plt.title(titulo)

    # Rotar las etiquetas del eje x para que sean legibles
    plt.xticks(rotation=45, ha='right')

    # Mostrar el gráfico
    plt.tight_layout()
    plt.show()
#3.4 Aquí compara dos listas de frecuencias y quita las x más repetidas coincidentes en cada texto.
#Quito las primeras 30 palabras que coinciden en el texto

def quitar_coincidencias(text, text1):
    # Dividir los textos en palabras
    palabras_texto1 = text.split()
    palabras_texto2 = text1.split()

    # Contar frecuencia de palabras en cada texto
    frecuencias_texto1 = Counter(palabras_texto1)
    frecuencias_texto2 = Counter(palabras_texto2)

    # Obtener las palabras más frecuentes en cada texto
    palabras_frecuentes_texto1 = [palabra for palabra, frecuencia in frecuencias_texto1.most_common()]
    palabras_frecuentes_texto2 = [palabra for palabra, frecuencia in frecuencias_texto2.most_common()]

    # Encontrar las palabras comunes más frecuentes
    palabras_comunes = set(palabras_frecuentes_texto1[:]).intersection(palabras_frecuentes_texto2[:])

    # Eliminar las palabras comunes más frecuentes
    texto1_sin_coincidencias = ' '.join([palabra for palabra in palabras_texto1 if palabra not in palabras_comunes])
    texto2_sin_coincidencias = ' '.join([palabra for palabra in palabras_texto2 if palabra not in palabras_comunes])

    return texto1_sin_coincidencias, texto2_sin_coincidencias

#va raro
def quitar_palabras(text,tex1):

    #divide el texto en cada palabrita
    text_words = text.split()
    text1_words = text1.split()

    #va por cada palabra del texto, y si coincide, la quita.
    for w in text1_words:
      text = text.replace(w, "")

    return text



#¡MIS DATOS!

#Datos de las mujeres.


# Leer el archivo CSV
df = pd.read_csv('/content/DatosTFG_columnas_hombre_mujer.csv')

# Traduzco el texto
df['Biografía'] = df['Biografía'].apply(traducir_texto_largo)



#Aplico a la biografía todas las cosas de pre-procesado.
df[['Biografía']] = df[['Biografía']].astype(str)
df['Biografía'] = df['Biografía'].apply(change_lower)
df['Biografía'] = df['Biografía'].apply(clean_data)
df['Biografía'] = df['Biografía'].apply(remover)
df['Biografía'] = df['Biografía'].apply(remover2)


#lo entreno para tener mi propio vocabulario.
w2v_df = get_w2vdf(df)
w2v_model = train_w2v(w2v_df)


#Lematizo todo.

df['Biografía'] = df['Biografía'].apply(eliminar_palabras_con_mismo_lema)

#lo junto todo en un string.
text = ' '.join(df['Biografía'])


#Crear lista con palabras más frecuentes en las biografías.

frecuencia_palabras = contar_frecuencia(text)
palabras_ordenadas = ordenar_por_frecuencia(text)
print(palabras_ordenadas)
print(frecuencia_palabras)







#CASO HOMBRES, COPIAR Y PEGAR


#Leo el archivo y lo paso a formado pandas, leíble y trabajable.
csv_path1 = '../content/DatosTFG_hombre.csv'
df1 = pd.read_csv(csv_path1)

#ya tengo las funciones puestas arriba, las uso

df1['Biografía'] = df1['Biografía'].apply(traducir_texto_largo)


df1[['Biografía']] = df1[['Biografía']].astype(str)
df1['Biografía'] = df1['Biografía'].apply(change_lower)
df1['Biografía'] = df1['Biografía'].apply(clean_data)
df1['Biografía'] = df1['Biografía'].apply(remover2)
df1['Biografía'] = df1['Biografía'].apply(remover)
df1['Biografía'] = df1['Biografía'].apply(eliminar_palabras_con_mismo_lema)

#Creo mi propio vocabulario entrenado.
w2v_df1 = get_w2vdf(df1)
w2v_model1 = train_w2v(w2v_df1)

#Lo junto en uno
text1 = ' '.join(df1['Biografía'])


#CASO DATOS TOTALES:

#Leo el archivo y lo paso a formado pandas, leíble y trabajable.
csv_path2 = '../content/DatosTFG.csv'
df2 = pd.read_csv(csv_path2)

#ya tengo las funciones puestas arriba, las uso

df2['Biografía'] = df2['Biografía'].apply(traducir_texto_largo)


df2[['Biografía']] = df2[['Biografía']].astype(str)
df2['Biografía'] = df2['Biografía'].apply(change_lower)
df2['Biografía'] = df2['Biografía'].apply(clean_data)
df2['Biografía'] = df2['Biografía'].apply(remover2)
df2['Biografía'] = df2['Biografía'].apply(remover)
df2['Biografía'] = df2['Biografía'].apply(eliminar_palabras_con_mismo_lema)

#Creo mi propio vocabulario entrenado.
w2v_df2 = get_w2vdf(df2)
w2v_model2 = train_w2v(w2v_df2)

#Lo junto en uno
text2 = ' '.join(df2['Biografía'])


#Frecuencias

palabras_ordenadas = ordenar_por_frecuencia(text1)
frecuencia_palabras = contar_frecuencia(text1)
print(palabras_ordenadas)
print(frecuencia_palabras)



texto1_sin_coincidencias, texto2_sin_coincidencias = quitar_coincidencias(text, text1)

print("Texto 1 sin las palabras coincidentes")
print(texto1_sin_coincidencias)

print("\nTexto 2 sin las palabras coincidentes")
print(texto2_sin_coincidencias)


# Generar Word Cloud para el Texto 1
generar_wordcloud(texto1_sin_coincidencias, "Word Cloud de las biografías de las Mujeres")

# Generar Word Cloud para el Texto 2
generar_wordcloud(texto2_sin_coincidencias, "Word Cloud de las biografías de los Hombres")

# Generar Word Cloud para el Texto 1
generar_wordcloud(text, "Word Cloud de las biografías de las Mujeres con las coincidencias")

# Generar Word Cloud para el Texto 2
generar_wordcloud(text1, "Word Cloud de las biografías de los Hombres con las coincidencias")



#Dibujar histograma SIN las primeras 30 palabras coincidentes

titulo = "Mujeres"
titulo1 = "Hombres"
dibujar_histograma(texto1_sin_coincidencias,titulo)
dibujar_histograma(texto2_sin_coincidencias,titulo1)

#Dibujar histograma CON las palabras coincidentes

dibujar_histograma(text,titulo)
dibujar_histograma(text1,titulo1)



#ANALISIS DE SENTIMIENTOS

#Iré metiendo cosillas.

#A ver qué sale

print('Las palabras más parecidas de woman')
a = w2v_model2.wv.most_similar(positive=["woman"])

print(a)


print('Las palabras más parecidas de man')
w2v_model2.wv.most_similar(positive=["man"])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ['university', 'research', 'spanish', 'work', 'scientific', 'professor', 'science', 'study', 'institute', 'year', 'award', 'researcher', 'partment', 'director', 'woman', 'thesis', 'publication', 'first', 'society', 'doctoral', 'national', 'council', 'member', 'international', 'group', 'center', 'madrid', 'field', 'vice', 'presint', 'velopment', 'project', 'gree', 'scientist', 'obtained', 'doctor', 'association', 'doctorate', 'graduated', 'biology', 'spain', 'new', 'magazine', 'career', 'higher', 'various', 'published', 'prize', 'csic', 'part', 'faculty', 'acamy', 'acamic', 'school', 'technology', 'area', 'received', 'state', 'began', 'royal', 'dicated', 'recognized', 'article', 'book', 'directed', 'specialized', 'recognition', 'life', 'foundation', 'board', 'participated', 'worked', 'teaching', 'position', 'among', 'professional', 'european', 'role', 'world', 'system', 'molecular', 'program', 'currently', 'committee', 'activity', 'united', 'carried', 'medicine', 'well', 'scholarship', 'co', 'general', 'author', 'addition', 'disease', 'postdoctoral', 'line', 'application', 'maría', 'dr', 'unr', 'appointed', 'medal', 'honor', 'end', 'trajectory', 'chair', 'laboratory', 'cell', 'barcelona', 'complutense', 'chemistry', 'process', 'together', 'commission', 'l', 'within', 'teacher', 'santiago', 'working', 'time', 'later', 'chemical', 'studied', 'direction', 'autonomous', 'management', 'biological', 'social', 'human', 'company', 'environmental', 'focused', 'different', 'use', 'related', 'master', 'history', 'section', 'natural', 'pharmacy', 'effect', 'health', 'education', 'result', 'service', 'conference', 'technological', 'created', 'found', 'granted', 'applied', 'knowledge', 'associated', 'josé', 'training', 'compostela', 'mainly', 'physic', 'several', 'stay', 'focus', 'organization', 'dissemination', 'analysis', 'engineering', 'stunt', 'april', 'january', 'numerous', 'ministry', 'technical', 'expert', 'level', 'head', 'method', 'ed', 'continued', 'born', 'isbn', 'responsible', 'cancer', 'based', 'biography', 'number', 'veloped', 'th', 'medical', 'evaluation', 'public', 'congress', 'collaboration', 'impact', 'important', 'institution', 'mechanism', 'coordinator', 'city', 'innovation', 'product', 'valencia', 'merit', 'present', 'x', 'course', 'held', 'community', 'catalan', 'central', 'data', 'young', 'contribution', 'consired', 'pier', 'agency', 'moved', 'relationship', 'name', 'issue', 'advisory', 'p', 'june', 'founr', 'support', 'government', 'computer', 'nerk', 'treatment', 'especially', 'journal', 'action', 'family', 'clinical', 'pp', 'subject', 'became', 'physical', 'great', 'studying', 'edition', 'current', 'editorial', 'culture', 'three', 'control', 'official', 'experimental', 'title', 'granada', 'conducted', 'union', 'collaborated', 'attached', 'special', 'polytechnic', 'november', 'reference', 'aging', 'environment', 'specialist', 'interaction', 'entitled', 'people', 'biomedical', 'innovative', 'type', 'alonso', 'protein', 'known', 'could', 'although', 'collaborator', 'technique', 'civil', 'best', 'daughter', 'catalonia', 'editor', 'six', 'specie', 'element', 'distinction', 'main', 'organized', 'galicia', 'museum', 'extraordinary', 'art', 'fernánz', 'third', 'led', 'joined', 'married', 'severo', 'ochoa', 'belonging', 'madridin', 'return', 'returned', 'cember', 'biochemistry', 'team', 'artificial', 'non', 'kingdom', 'hundred', 'promote', 'following', 'presence', 'presented', 'diagnosis', 'patient', 'american', 'strategy', 'basic', 'chapter', 'outstanding', 'many', 'alzheimers', 'commitment', 'vol', 'framework', 'excellence', 'gene', 'online', 'juan', 'gonzález', 'therapeutic', 'english', 'specializing', 'four', 'investigation', 'cause', 'high', 'meeting', 'war', 'attend', 'problem', 'miguel', 'due', 'economic', 'gold', 'industrial', 'material', 'place', 'review', 'educational', 'long', 'ramón', 'right', 'importance', 'last', 'specifically', 'corresponding', 'july', 'table', 'directs', 'secretary', 'change', 'large', 'local ...
# {'biology': 22, 'researcherhe': 3, 'major': 2, 'world': 16, 'completed': 5, 'phd': 5, 'joined': 6, 'direction': 12, 'married': 6, 'work': 48, 'shortly': 1, 'granada': 7, 'madrid': 26, 'specified': 1, 'addition': 15, 'schizophrenia': 1, 'scientific': 47, 'access': 4, 'physiology': 5, 'system': 16, 'research': 59, 'position': 17, 'interested': 4, 'base': 5, 'molecular': 16, 'glycinergic': 1, 'severo': 6, 'set': 5, 'ochoa': 6, 'titular': 4, 'professor': 46, 'university': 64, 'named': 2, 'trainingupon': 1, 'center': 27, 'autonomous': 12, 'gree': 25, 'institute': 41, 'belonging': 6, 'madridin': 6, 'neuromuscular': 1, 'officebut': 1, 'universityand': 1, 'return': 6, 'council': 29, 'birmingham': 1, 'returned': 6, 'childrenresearch': 1, 'moved': 8, 'functioning': 1, 'partment': 33, 'disease': 15, 'cember': 6, 'spain': 22, 'investigated': 5, 'obtained': 23, 'relationship': 8, 'higher': 21, 'researchin': 1, 'uam': 3, 'neurotransmissionin': 1, 'postdoctoral': 15, 'faculty': 20, 'biochemistry': 6, 'universityfrom': 2, 'field': 26, 'vision': 2, 'zaragozafrom': 1, 'nervous': 3, 'team': 6, 'pharmacy': 11, 'line': 15, 'magnificent': 2, 'program': 16, 'currently': 16, 'argentinain': 2, 'novartis': 1, 'electric': 2, 'self': 1, 'invasive': 1, 'veloped': 9, 'apraxiaendocrinology': 1, 'member': 29, 'patientsactive': 1, 'mining': 3, 'engineering': 10, 'wearable': 1, 'dicated': 19, 'vice': 26, 'management': 12, 'microelectronic': 1, 'dilated': 1, 'signal': 2, 'thesespublished': 1, 'achievement': 2, 'en': 1, 'effect': 11, 'conducted': 7, 'end': 14, 'sept': 1, 'complete': 1, 'trajectory': 14, 'ihealth': 1, 'internationally': 3, 'isahp': 1, 'committee': 16, 'upmrobotics': 1, 'name': 8, 'cision': 3, 'daily': 2, 'affair': 2, 'health': 11, 'sector': 5, 'union': 7, 'promotion': 1, 'first': 30, 'allows': 3, 'fibrillatory': 1, 'ict': 4, 'issue': 8, 'vojext': 1, 'broad': 1, 'advisory': 8, 'application': 15, 'houssay': 1, 'ingebiomedical': 1, 'among': 17, 'administration': 5, 'ehealth': 1, 'th': 9, 'piering': 1, 'presint': 26, 'medical': 9, 'multidisciplinary': 2, 'integrated': 2, 'education': 11, 'argentine': 3, 'spainin': 1, 'p': 8, 'home': 1, 'communication': 5, 'manyothersit': 1, 'disadvantaged': 1, 'cortical': 1, 'directed': 18, 'evaluation': 9, 'founding': 4, 'mr': 4, 'thesis': 32, 'lifehis': 1, 'planact': 1, 'projectsamong': 1, 'fellow': 5, 'accessibility': 1, 'sciencedirector': 1, 'collaborated': 7, 'activity': 16, 'artificial': 6, 'specialized': 18, 'ahp': 1, 'plan': 5, 'completely': 2, 'recognition': 18, 'public': 9, 'biological': 12, 'societyresearch': 1, 'etsit': 1, 'interactive': 2, 'societydirector': 1, 'transfer': 3, 'platform': 2, 'ischemia': 1, 'intelligence': 5, 'social': 12, 'living': 2, 'socio': 2, 'livinglabsin': 1, 'qualified': 1, 'lifespace': 1, 'post': 2, 'nutrition': 2, 'acute': 4, 'smartex': 1, 'congress': 9, 'recognized': 19, 'cardiology': 2, 'allowing': 1, 'forum': 4, 'unionhis': 1, 'stunt': 10, 'leloir': 1, 'etcfacilitate': 1, 'highly': 2, 'test': 2, 'june': 8, 'vocation': 2, 'orientation': 1, 'telemedicine': 2, 'drug': 4, 'iot': 1, 'extensive': 3, 'founr': 8, 'textile': 1, 'collaboration': 9, 'teresa': 4, 'open': 3, 'good': 5, 'luminotechnics': 2, 'diseasesin': 1, 'support': 8, 'non': 6, 'private': 4, 'pologiesoncology': 1, 'impact': 9, 'international': 29, 'human': 12, 'performing': 2, 'located': 5, 'london': 3, 'monitoring': 4, 'spainhe': 3, 'improvement': 5, 'company': 12, 'mental': 1, 'united': 16, 'attached': 7, 'conduct': 3, 'important': 9, 'moncloa': 1, 'kingdom': 6, 'lab': 1, 'campusmerit': 1, 'agriculture': 5, 'professional': 17, 'result': 11, 'contributed': 3, 'institution': 9, 'monstrate': 3, 'hundred': 6, 'director': 33, 'nokia': 1, 'april': 10, 'healthin': 1, 'arredondo': 1, 'environmental': 12, 'agreement': 2, 'symposium': 4, 'intense': 3, 'specification': 3, 'promote': 6, 'following': 6, 'telemedicina': 2, 'velops': 2, 'cluster': 2, 'exchange': 5, 'external': 5, 'pub': 1, 'maria': 3, 'special': 7, 'service': 11, 're ...
# ['university', 'research', 'professor', 'spanish', 'scientific', 'science', 'study', 'director', 'national', 'member', 'award', 'work', 'institute', 'doctor', 'center', 'prize', 'published', 'article', 'researcher', 'international', 'received', 'doctorate', 'new', 'year', 'partment', 'european', 'society', 'council', 'first', 'madrid', 'scientist', 'american', 'field', 'publication', 'medicine', 'group', 'united', 'school', 'spain', 'magazine', 'career', 'book', 'health', 'well', 'acamy', 'causa', 'honoris', 'foundation', 'project', 'among', 'state', 'worked', 'faculty', 'world', 'author', 'presint', 'area', 'thesis', 'doctoral', 'addition', 'numerous', 'velopment', 'jaime', 'royal', 'born', 'graduated', 'postdoctoral', 'barcelona', 'contribution', 'biology', 'various', 'training', 'category', 'appointed', 'acamic', 'molecular', 'collaboration', 'honor', 'higher', 'education', 'studied', 'association', 'obtained', 'professional', 'hospital', 'medical', 'outstanding', 'san', 'recognition', 'cited', 'technology', 'participated', 'later', 'program', 'dr', 'currently', 'five', 'chemical', 'high', 'began', 'granted', 'activity', 'several', 'laboratory', 'process', 'recognized', 'technical', 'committee', 'king', 'position', 'gree', 'disease', 'biomedical', 'team', 'part', 'medal', 'l', 'distinguished', 'innovation', 'direction', 'vice', 'institution', 'physic', 'physical', 'valencia', 'veloped', 'chemistry', 'different', 'orr', 'head', 'journal', 'chapter', 'biography', 'complutense', 'ministry', 'great', 'subject', 'cancer', 'life', 'time', 'government', 'best', 'review', 'advanced', 'country', 'dissemination', 'excellence', 'application', 'polytechnic', 'working', 'moved', 'csic', 'grant', 'stay', 'focus', 'directed', 'focused', 'co', 'natural', 'juan', 'scholarship', 'dicated', 'technique', 'sport', 'gonzález', 'engineering', 'management', 'j', 'communication', 'system', 'environment', 'basic', 'isbn', 'college', 'impact', 'june', 'following', 'together', 'merit', 'creation', 'analysis', 'autonomous', 'unr', 'march', 'chair', 'carried', 'created', 'division', 'mechanism', 'distinction', 'investigation', 'according', 'clinical', 'art', 'applied', 'known', 'carlos', 'service', 'specialized', 'held', 'level', 'taught', 'ed', 'rey', 'congress', 'conference', 'interaction', 'miguel', 'may', 'unit', 'january', 'city', 'honorary', 'board', 'teacher', 'josé', 'r', 'internationally', 'culture', 'special', 'main', 'york', 'based', 'editor', 'gene', 'effect', 'important', 'knowledge', 'organization', 'public', 'asturias', 'harvard', 'many', 'british', 'stunt', 'specialist', 'large', 'specialty', 'today', 'others', 'human', 'master', 'throughout', 'quality', 'information', 'industry', 'technological', 'medium', 'use', 'change', 'social', 'engineer', 'future', 'c', 'place', 'quantum', 'trajectory', 'bbva', 'return', 'appointment', 'material', 'written', 'within', 'sign', 'cruz', 'formation', 'germany', 'granada', 'structure', 'led', 'disseminator', 'related', 'became', 'newspaper', 'initiative', 'hundred', 'computer', 'theoretical', 'issue', 'last', 'line', 'directs', 'physicist', 'editorial', 'blog', 'advisory', 'civil', 'h', 'direct', 'interest', 'cember', 'nature', 'name', 'selection', 'cell', 'gran', 'treatment', 'catalonia', 'writer', 'april', 'hernánz', 'chosen', 'paris', 'took', 'non', 'company', 'basque', 'four', 'official', 'general', 'digital', 'nerks', 'food', 'returned', 'prestigious', 'ofthe', 'coordinator', 'valencian', 'teaching', 'greatest', 'governing', 'x', 'pharmacy', 'santiago', 'complex', 'discovery', 'twenty', 'promotion', 'collaborated', 'informative', 'way', 'aspect', 'discovered', 'atomic', 'salamanca', 'visiting', 'microbiology', 'global', 'patent', 'early', 'section', 'collaborator', 'joint', 'ramón', 'earth', 'selected', 'elected', 'environmental', 'climate', 'th', 'ecology', 'founr', 'died', 'expert', 'history', 'october', 'september', 'gold', 'b', 'europe', 'community', 'data', 'thirteen', 'composed', 'prince', ' ...
# {'biology': 13, 'diffusion': 1, 'currently': 11, 'seminar': 2, 'work': 31, 'salzburg': 1, 'scientific': 42, 'cultural': 3, 'secondary': 3, 'fullbrighthys': 1, 'yearshe': 1, 'center': 28, 'united': 19, 'england': 3, 'harvard': 6, 'allhe': 1, 'admitted': 1, 'experimental': 1, 'american': 21, 'higher': 12, 'published': 27, 'field': 21, 'austriahe': 1, 'organized': 4, 'indicated': 1, 'school': 19, 'received': 24, 'thanks': 2, 'research': 46, 'professor': 44, 'spanish': 44, 'applied': 7, 'spiritual': 1, 'among': 16, 'participate': 2, 'juan': 8, 'publishing': 3, 'bilbaohe': 2, 'horticulture': 1, 'known': 7, 'doctor': 30, 'friendship': 2, 'edaphology': 1, 'education': 12, 'biologisthe': 1, 'station': 2, 'christian': 1, 'many': 6, 'thesis': 14, 'safe': 3, 'science': 41, 'futiculture': 1, 'prize': 28, 'cuorniú': 1, 'council': 22, 'great': 9, 'state': 16, 'long': 4, 'five': 11, 'partment': 23, 'chemical': 11, 'essay': 2, 'studied': 12, 'varied': 1, 'gaztelueta': 1, 'british': 6, 'doctoral': 14, 'resis': 1, 'bristol': 2, 'various': 13, 'well': 17, 'ashton': 1, 'stunt': 6, 'worked': 16, 'university': 48, 'researcher': 26, 'subject': 9, 'morality': 1, 'stand': 3, 'writer': 5, 'study': 35, 'scholarship': 8, 'record': 2, 'beingdoctor': 1, 'initiating': 1, 'passing': 3, 'ile': 1, 'child': 4, 'rank': 1, 'si': 1, 'club': 3, 'international': 26, 'cancer': 9, 'clinicafter': 1, 'life': 9, 'followed': 2, 'serious': 1, 'roller': 1, 'member': 32, 'association': 12, 'dicated': 8, 'scarcity': 1, 'captain': 2, 'high': 11, 'foral': 1, 'fosbury': 1, 'dorsal': 1, 'champion': 1, 'munich': 1, 'french': 2, 'lau': 1, 'specialist': 6, 'article': 27, 'conducted': 4, 'amateur': 1, 'navarro': 2, 'highlight': 2, 'large': 6, 'training': 13, 'like': 1, 'category': 13, 'lete': 2, 'scaniapamplona': 1, 'obtained': 12, 'professional': 12, 'began': 11, 'knee': 1, 'silver': 2, 'personal': 4, 'family': 4, 'team': 10, 'april': 5, 'granted': 11, 'mateo': 2, 'camino': 1, 'brand': 2, 'ana': 2, 'award': 32, 'addition': 14, 'first': 22, 'specialty': 6, 'olympics': 1, 'today': 6, 'tartan': 1, 'carlos': 7, 'salto': 1, 'plaza': 3, 'injury': 1, 'neglect': 1, 'othersthis': 1, 'getting': 2, 'jumpduring': 1, 'invented': 1, 'letes': 1, 'pamplonahe': 1, 'european': 23, 'hospital': 12, 'service': 7, 'receiving': 1, 'publication': 21, 'portland': 1, 'titlesmeanwhile': 1, 'beat': 1, 'pamplona': 2, 'part': 10, 'lawyer': 1, 'letic': 1, 'historic': 1, 'cum': 1, 'formed': 2, 'economist': 1, 'movedsports': 1, 'surgery': 4, 'medal': 10, 'technique': 8, 'time': 9, 'medical': 12, 'sport': 8, 'medicine': 21, 'hernánz': 5, 'colon': 1, 'fernando': 3, 'outstanding': 12, 'caun': 1, 'competition': 2, 'height': 1, 'government': 9, 'share': 2, 'national': 33, 'gainin': 1, 'trophy': 1, 'chief': 2, 'francethey': 1, 'villava': 1, 'founding': 3, 'san': 12, 'youth': 2, 'virgen': 2, 'helicobacter': 1, 'associate': 4, 'chosen': 5, 'amounted': 1, 'l': 10, 'activity': 11, 'dicates': 1, 'specialized': 7, 'subsequently': 4, 'several': 11, 'recognition': 12, 'highlighting': 1, 'borda': 2, 'pology': 4, 'iturri': 1, 'bronze': 1, 'cyclist': 1, 'step': 2, 'maximum': 2, 'doctorate': 24, 'held': 7, 'cited': 12, 'navarrese': 1, 'garralda': 1, 'faculty': 16, 'gonzález': 8, 'paris': 5, 'feat': 1, 'native': 1, 'style': 1, 'best': 9, 'laua': 1, 'stood': 3, 'right': 2, 'town': 2, 'world': 16, 'peculiar': 1, 'jump': 1, 'finitively': 2, 'occupation': 1, 'others': 6, 'madrid': 22, 'antonio': 4, 'top': 1, 'reaching': 1, 'sportdoctor': 1, 'handball': 1, 'digestive': 1, 'test': 1, 'atlético': 1, 'pylorus': 1, 'championship': 1, 'occasion': 2, 'letics': 1, 'figure': 1, 'dick': 1, 'heightit': 1, 'took': 5, 'played': 1, 'caunand': 1, 'exatleta': 1, 'spain': 19, 'achieved': 4, 'junior': 1, 'distinguished': 10, 'jumpchildhood': 1, 'magazine': 19, 'contestin': 1, 'gastroenterology': 1, 'cycling': 1, 'coinciding': 1, 'opposition': 1, 'miguelinduráin': 1, 'reason': 2, 'daughter': 2, 'collaboratingin': 1, 'revolution': 2, 'non': 5, 'usto': 1, 's ...
# Texto 1 sin las palabras coincidentes
# researcherhe major married specified schizophrenia glycinergic named trainingupon neuromuscular officebut universityand birmingham childrenresearch researchin neurotransmissionin zaragozafrom nervous argentinain novartis electric apraxiaendocrinology patientsactive wearable microelectronic dilated signal thesespublished en sept complete ihealth isahp upmrobotics cision allows fibrillatory vojext broad houssay ingebiomedical ehealth multidisciplinary argentine spainin manyothersit cortical lifehis planact projectsamong accessibility sciencedirector ahp completely societyresearch etsit interactive societydirector ischemia socio livinglabsin qualified lifespace smartex unionhis leloir etcfacilitate orientation telemedicine iot extensive textile teresa good luminotechnics diseasesin pologiesoncology located moncloa campusmerit nokia healthin arredondo specification promote telemedicina pub maria requirement madridmobihealth lifehe microsoft healthand researchersandor aha yearsshe technologiessmart sabi technologiescoordinator parkinson involvedthe resuscitation ipneuronal needshigher instrumental expand rehabilitation electrician argentinasubsequently panvitapharmacology prima repussion pilot lifestylepsychiatry throughouttheir psychologiststhe transventricular healthcare samsung etsitupmadvisor segura automatic introduced qdictated respiratory niería careeraward enhancing cao dkv discharge philip lifestech threshold need implemented wireless contextthese nerkputy sensor initiator prominent facebook scenario transforming eliciation rectorate needshe conditionshis rectorateof cancerneurology missing imserso respond foglia multiformat postrecruitment servicesto diabetic entity accessible flag healthcareth fieldthe mobile configures isap universal actorsthe theseshe hygiene puzzle bernardo multicentric inpennce automotic nyas eit implementation predict pre ata lifein dressed safety livinglabs torressee activage dresv fibrillation periscope pharmaledger prolific domotized failure theinpennt ahpin workbiography generated engineerig waldmeyer occlusioncourt signer spectrum pulse wi peoplethis americadirector transaction lst upmthe acamicscientific proceeding conferencesparticipated bioengineering pologies sexenciesmaría medtronic prevent alzheimers assisted renewal vodaf follow projectacamic barcelonacovid imi woman stroke leading withnumerous brilliant inclusion neuronal agenciesin pe companyhe tucumán researchshe intensify casessign ip markedly infoaccessibility seib magnifico type moll sala garcíaarguinzonis neuronrned lrp low statin receptor lluís receiver initiatedhe apoptosis physiologist covered copy cellsclinic extra infarcionclinic myocardial hifa badimon gemma castilian tpadró benefit orphan judith painted cardiac endothelial sendra martorell serum vascular cubedo maisa cristina esci aledo societyfor polymorphism acronym lesion premature muscle rosuvastatin hypholesterolemiaspanish researchclinical llorente vicenta barceloanfor rosuvastatina mata lipoproteinsclinic prevents proteome hypoxia paula crespo maestro vilahurclinical costales cinca spectrumspanish castellano cholesterol rodrigo arteriosclerosishe smooth transcription proteomic stimulates good lina bound expectation taub thecolumbia barié veteran neurogenerative diseasethe apolipoprotein think diseaseit play late precursor bleak susceptibility intify spainunfortunately barral pessimism however allele age gertru ailment preventivethrough evince variation sporadic leap abandoning alzheimers alzheimertherapeutic increasing absence onset disorrsaccording completely mapping worsens professionthis cidhe recently amyloid diseasebiography lareu cumc preseniline convincing inheritance suggest sergievsky etiology maza velopmentthe neurogenetic microorganism charge precariousdue affairsmadrids norman physikalische cierva pontifical hidalgo trainingthroughout low warlike beer sedo calatravabefore totally calzada arrived recognitionministry encouraged cyril meet plateinstitutional ...
#
# Texto 2 sin las palabras coincidentes
# diffusion salzburg fullbrighthys harvard allhe austriahe spiritual horticulture friendship safe futiculture cuorniú varied gaztelueta bristol ashton morality beingdoctor initiating passing ile rank si clinicafter followed roller scarcity captain foral fosbury dorsal champion munich lau amateur like lete scaniapamplona knee mateo camino brand olympics tartan salto neglect othersthis jumpduring invented letes pamplonahe receiving portland titlesmeanwhile beat pamplona letic historic cum economist movedsports colon caun height gainin trophy francethey villava virgen helicobacter amounted highlighting borda iturri cyclist navarrese garralda feat native style laua town peculiar jump finitively reaching sportdoctor handball atlético pylorus championship letics dick heightit took caunand exatleta junior jumpchildhood contestin gastroenterology cycling coinciding miguelinduráin collaboratingin revolution claim datal okp icts sciencebusiness factory economista cyber repair competitivenessedicis tomorrow offering scheduling thefactory produce systempant thermoplastic systemsdyna mrp cim andit philosophical practically small researcherprofessional organizational skeptical technologiesbulletin protectionism quantitative pillar entrepreneurhe create concurrent automotiveautomotive epened extinct vvaa sustainability itfor optimize legate dordrechtjavier daysnanoproductsmagazine multinational operate competitivenessbulletin habitabilityand launch classroomaeronautics maintenance interpreter diario borda ifip systemplant machine ceo processing elejabarrieta digitalization experimenting futurehuman computerized noting existentfor plantseditorial mere conceptsapplication injection projectsit hodie correspond digitaleditorial maneditorial sectorqualitas etsii systemant automotive worth systemsmro moreeditorial caution iteam quevedo photonic capmany awardof osa ecoc educationhe cost valenciainvestigate iethe particularly physicsfoundation appreciable ardo systemscapmany forimprove broadband speed crease areaof projecting madridthen coiaclche palencia león affirming transferred treasury lxv vowel vote half purple legate possession butler villagehe areatogether let absent machinery fallen machine cyted winery vast imparting burgos replacing arsenal enoologythe took enoological party leaf enriching ac asnumber internationalfor mariosimón palenciaas uvamox politician paloma armed uvaprofessional engineerdoctor palenciaon writes goal lieutenant nationally upvhe finance positionin paradoxically gutiérrezas monday leónand satragsa office requean happening luismiguel win femp navyfirst leaving approval military pure enology ensuring ensign bari bioprocess frigate sciencebusiness hiring plenary absolute ace majority sublegate yutero councilor homeland nerkhe stewardship contracting requenait consistoryearly andrésalthough universityluis ofagronomic requena medrano hard therereturn lost oenological easter assured profionion legated currentlyit sergio ofthis satisfied ramiro rebollar corporation sublegation noted cárcel polanco oenology winegovernment careerafter nicolás viticulture palenciafinally cityin countrysi honored girviten seat engineeringagrarian gutiérrez aula councilors provincehe yearsagricultural prison join happens holy maintenance vitivinícola behind victory commissionnavalrecognitions ortega requenaof greewithin citizen agriculturehis election housewifewhen rectorit magazinesin socialist xix miriam vitiviniculture signand income accession inorganic ditiooxamis adduct wissenschaftliches joachim kololquium wissenschaftlicher crystallógraphic xiiith tetrahaluros advancement sciencesduring bagsof strähle arbeitsgrupen purposein diffraction attachment utscher zeitschrift housemember tübingen spanishiallian graphic cristlolelgraphie hiller meetingsboth magazinedistinctions sagrario anorganische marburg masaguer latinamerican gesellschaft polyhedron magazinemember agreed groupsportuguese chemistryphysics severino sponsountil cloister française wol ...
# Las palabras más parecidas de woman
# [('room', 0.7322279214859009), ('writing', 0.7164896130561829), ('husband', 0.7069154381752014), ('greatest', 0.7036198973655701), ('ignacio', 0.6955750584602356), ('studying', 0.695142924785614), ('produced', 0.6950466632843018), ('although', 0.6939982175827026), ('affected', 0.6825084090232849), ('renowned', 0.6746405363082886)]
# Las palabras más parecidas de man
# [('theory', 0.7631304860115051),
#  ('british', 0.7602491974830627),
#  ('loss', 0.7500819563865662),
#  ('business', 0.7498015761375427),
#  ('biotechnology', 0.7490454912185669),
#  ('stood', 0.7421118021011353),
#  ('infectious', 0.7362241148948669),
#  ('nutrition', 0.7342941761016846),
#  ('fruitful', 0.7319362759590149),
#  ('supervision', 0.7309848666191101)]
